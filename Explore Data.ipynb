# %%
from google.colab import drive
drive.mount('/content/Mydrive')
# Out:
# Mounted at /content/Mydrive

# %%
import nltk
from nltk import unique_list
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import numpy as np
import pandas as pd

# %%
def load_vocabs(name_file):
  V = None
  with open(name_file, "r") as f:
    V = f.readlines()
    V = list(map(lambda  x:x.strip("\n") , V))
  return V

# %%
new_word_data = load_vocabs("/content/Mydrive/MyDrive/CS221 - Xử lý ngôn ngữ tự nhiên/Đồ án NLP/wikitext-2/word_data_wikitext_2_test.txt")

# %%
len(new_word_data)
# Out:
# 9574

# %%
number_word = 0
for sent in new_word_data:
    number_word += len(sent.split())

# %%
number_word
# Out:
# 217365
